# %% [markdown]
# # Preliminaries

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn import preprocessing
import torch
import datawig

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv("dat.csv", index_col=0)
data.head()
# Out:
#    inpatient.number DestinationDischarge admission.ward admission.way  \
# 1            857781                 Home     Cardiology  NonEmergency
# 2            743087                 Home     Cardiology  NonEmergency
# 3            866418                 Home     Cardiology  NonEmergency
# 4            775928                 Home     Cardiology     Emergency
# 5            810128                 Home     Cardiology  NonEmergency
#
#       occupation discharge.department  visit.times  gender  body.temperature  \
# 1  UrbanResident           Cardiology            1    Male              36.7
# 2  UrbanResident           Cardiology            1  Female              36.8
# 3         farmer           Cardiology            2    Male              36.5
# 4  UrbanResident           Cardiology            1    Male              36.0
# 5  UrbanResident           Cardiology            1  Female              35.0
#
#    pulse  ...  body.temperature.blood.gas  oxygen.saturation  \
# ...

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2008 entries, 1 to 2008
# Data columns (total 166 columns):
#  #    Column                                                         Dtype
# ---   ------                                                         -----
#  0    inpatient.number                                               int64
#  1    DestinationDischarge                                           object
#  2    admission.ward                                                 object
#  3    admission.way                                                  object
#  4    occupation                                                     object
#  5    discharge.department                                           object
#  6    visit.times                                                    int64
#  7    gender                                                         object
#  8    body.temperature                                               float64
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Prepare Data for Processing

# %% [markdown]
# In order to prepare some of our data, we should use one hot encoding to encode our categorical data. We also must manually make sure that each covariate has the right data type.

# %% [markdown]
# ## Impute Missing Data

# %% [markdown]
# Now that our data is encoded, we can impute missing values. We will use a model to predict the missing values. We only want to consider columns that do not have too much data missing and we'll use a threshold of 10% for that. We'll also assume that the data is missing completely at random (MCAR) in order to perform this imputation.

# %% [markdown]
# ## Transformations

# %% [markdown]
# ## Randomization

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ## Split

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Training

# %% [markdown]
# ## Evaluation
